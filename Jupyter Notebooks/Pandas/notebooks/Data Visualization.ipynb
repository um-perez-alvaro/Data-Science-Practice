# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Visualization

# %% [markdown]
# The `Traffic_Crashes_-_Crashes.csv` file  shows information about each traffic crash on city streets within the City of Chicago limits and under the jurisdiction of Chicago Police Department (CPD).
# It can be downloaded from this [link](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Crashes/85ca-t3if).

# %%
data = pd.read_csv('C:\\Users\javier.perez-alvaro\\Downloads\\Traffic_Crashes_-_Crashes.csv', index_col = 'CRASH_DATE', parse_dates=True)
data.head()
# Out:
#                                                        CRASH_RECORD_ID  \
# CRASH_DATE
# 2022-07-15 00:45:00  0115ade9a755e835255508463f7e9c4a9a0b47e9304238...
# 2022-07-15 18:50:00  017040c61958d2fa977c956b2bd2d6759ef7754496dc96...
# 2022-07-15 17:10:00  01aaa759c6bbefd0f584226fbd88bdc549de3ed1e46255...
# 2022-07-15 08:44:00  0362b3f8ddb8589dfe889356efbc2ad213efe2031556f0...
# 2022-07-15 16:10:00  03d3679ef44bb8aa0f2060cb0376f3eeb1d9dbb2197322...
#
#                         RD_NO CRASH_DATE_EST_I  POSTED_SPEED_LIMIT  \
# CRASH_DATE
# 2022-07-15 00:45:00  JF318029              NaN                  30
# 2022-07-15 18:50:00  JF324552              NaN                  30
# 2022-07-15 17:10:00  JF319819              NaN                  40
# 2022-07-15 08:44:00  JF318271              NaN                  30
# 2022-07-15 16:10:00  JF318956              NaN                  30
#
#                     TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION  \
# CRASH_DATE
# 2022-07-15 00:45:00                UNKNOWN               UNKNOWN
# 2022-07-15 18:50:00         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 2022-07-15 17:10:00            NO CONTROLS           NO CONTROLS
# 2022-07-15 08:44:00            NO CONTROLS           NO CONTROLS
# 2022-07-15 16:10:00      STOP SIGN/FLASHER  FUNCTIONING PROPERLY
#
#                     WEATHER_CONDITION      LIGHTING_CONDITION  \
# CRASH_DATE
# 2022-07-15 00:45:00             CLEAR  DARKNESS, LIGHTED ROAD
# 2022-07-15 18:50:00             CLEAR                DAYLIGHT
# 2022-07-15 17:10:00   CLOUDY/OVERCAST                DAYLIGHT
# 2022-07-15 08:44:00              RAIN                DAYLIGHT
# 2022-07-15 16:10:00              RAIN                DAYLIGHT
#
#                     FIRST_CRASH_TYPE                  TRAFFICWAY_TYPE  ...  \
# CRASH_DATE                                                             ...
# 2022-07-15 00:45:00            ANGLE                      NOT DIVIDED  ...
# 2022-07-15 18:50:00         REAR END                      NOT DIVIDED  ...
# 2022-07-15 17:10:00            ANGLE       DIVIDED - W/MEDIAN BARRIER  ...
# 2022-07-15 08:44:00         REAR END  DIVIDED - W/MEDIAN (NOT RAISED)  ...
# 2022-07-15 16:10:00       PEDESTRIAN                         FOUR WAY  ...
#
#                      INJURIES_NON_INCAPACITATING  \
# CRASH_DATE
# 2022-07-15 00:45:00                          0.0
# 2022-07-15 18:50:00                          0.0
# 2022-07-15 17:10:00                          0.0
# 2022-07-15 08:44:00                          0.0
# 2022-07-15 16:10:00                          1.0
#
#                     INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION  \
# CRASH_DATE
# 2022-07-15 00:45:00                           0.0                    2.0
# 2022-07-15 18:50:00                           0.0                    2.0
# 2022-07-15 17:10:00                           0.0                    2.0
# 2022-07-15 08:44:00                           0.0                    3.0
# 2022-07-15 16:10:00                           0.0                    1.0
#
#                     INJURIES_UNKNOWN CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH  \
# CRASH_DATE
# 2022-07-15 00:45:00              0.0          0                 6           7
# 2022-07-15 18:50:00              0.0         18                 6           7
# 2022-07-15 17:10:00              0.0         17                 6           7
# 2022-07-15 08:44:00              0.0          8                 6           7
# 2022-07-15 16:10:00              0.0         16                 6           7
#
#                       LATITUDE  LONGITUDE  \
# CRASH_DATE
# 2022-07-15 00:45:00  41.886336 -87.716203
# 2022-07-15 18:50:00  41.925111 -87.667997
# 2022-07-15 17:10:00  41.975826 -87.650420
# 2022-07-15 08:44:00  41.944199 -87.747157
# 2022-07-15 16:10:00  41.855974 -87.663860
#
#                                                      LOCATION
# CRASH_DATE
# 2022-07-15 00:45:00  POINT (-87.716203130599 41.886336409761)
# 2022-07-15 18:50:00  POINT (-87.667997321599 41.925110815832)
# 2022-07-15 17:10:00  POINT (-87.650419778017 41.975826016449)
# 2022-07-15 08:44:00  POINT (-87.747157281564 41.944198992304)
# 2022-07-15 16:10:00  POINT (-87.663860117648 41.855973928536)
#
# [5 rows x 48 columns]

# %%
# sort index
data.sort_index(inplace=True)
data.head()
# Out:
#                                                        CRASH_RECORD_ID  \
# CRASH_DATE
# 2013-03-03 16:48:00  a802658be15312809c771559e4f81088cfb226830792a5...
# 2013-06-01 20:29:00  19fb5af681f833c2af85734245f737fa6fbe62ac1ea379...
# 2014-01-18 18:14:00  f62e27317feb174811cf4fefeb9fa1064fea6c0619a873...
# 2014-01-21 07:40:00  957783a4787318f005a7dbc920e4c84cb9ac8aa7329a62...
# 2014-02-24 19:45:00  1d0232afecbdfd01968555aa956a688fd6f55a2bd1984f...
#
#                         RD_NO CRASH_DATE_EST_I  POSTED_SPEED_LIMIT  \
# CRASH_DATE
# 2013-03-03 16:48:00  JC172482              NaN                  30
# 2013-06-01 20:29:00  JF358092              NaN                  30
# 2014-01-18 18:14:00  JB442550              NaN                  30
# 2014-01-21 07:40:00  HZ122950              NaN                  30
# 2014-02-24 19:45:00  HZ164689              NaN                  30
#
#                     TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION  \
# CRASH_DATE
# 2013-03-03 16:48:00         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 2013-06-01 20:29:00            NO CONTROLS           NO CONTROLS
# 2014-01-18 18:14:00            NO CONTROLS           NO CONTROLS
# 2014-01-21 07:40:00                  YIELD           NO CONTROLS
# 2014-02-24 19:45:00         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
#
#                     WEATHER_CONDITION      LIGHTING_CONDITION  \
# CRASH_DATE
# 2013-03-03 16:48:00             CLEAR                DAYLIGHT
# 2013-06-01 20:29:00             CLEAR  DARKNESS, LIGHTED ROAD
# 2014-01-18 18:14:00             CLEAR                    DUSK
# 2014-01-21 07:40:00             CLEAR                DAYLIGHT
# 2014-02-24 19:45:00              RAIN                DAYLIGHT
#
#                                  FIRST_CRASH_TYPE  \
# CRASH_DATE
# 2013-03-03 16:48:00  SIDESWIPE OPPOSITE DIRECTION
# 2013-06-01 20:29:00                    PEDESTRIAN
# 2014-01-18 18:14:00          PARKED MOTOR VEHICLE
# 2014-01-21 07:40:00                         ANGLE
# 2014-02-24 19:45:00                       TURNING
#
#                                      TRAFFICWAY_TYPE  ...  \
# CRASH_DATE                                            ...
# 2013-03-03 16:48:00                      NOT DIVIDED  ...
# 2013-06-01 20:29:00                      NOT DIVIDED  ...
# 2014-01-18 18:14:00       DIVIDED - W/MEDIAN BARRIER  ...
# 2014-01-21 07:40:00  DIVIDED - W/MEDIAN (NOT RAISED)  ...
# 2014-02-24 19:45:00                      NOT DIVIDED  ...
#
#                      INJURIES_NON_INCAPACITATING  \
# CRASH_DATE
# 2013-03-03 16:48:00                          0.0
# 2013-06-01 20:29:00                          1.0
# 2014-01-18 18:14:00                          0.0
# 2014-01-21 07:40:00                          1.0
# 2014-02-24 19:45:00                          0.0
#
#                     INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION  \
# CRASH_DATE
# 2013-03-03 16:48:00                           2.0                    1.0
# 2013-06-01 20:29:00                           0.0                    1.0
# 2014-01-18 18:14:00                           0.0                    2.0
# 2014-01-21 07:40:00                           0.0                    1.0
# 2014-02-24 19:45:00                           0.0                    2.0
#
#                     INJURIES_UNKNOWN CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH  \
# CRASH_DATE
# 2013-03-03 16:48:00              0.0         16                 1           3
# 2013-06-01 20:29:00              0.0         20                 7           6
# 2014-01-18 18:14:00              0.0         18                 7           1
# 2014-01-21 07:40:00              0.0          7                 3           1
# 2014-02-24 19:45:00              0.0         19                 2           2
#
#                       LATITUDE  LONGITUDE  \
# CRASH_DATE
# 2013-03-03 16:48:00  41.975857 -87.708744
# 2013-06-01 20:29:00  42.005145 -87.689969
# 2014-01-18 18:14:00  41.885610 -87.638756
# 2014-01-21 07:40:00  41.760710 -87.561946
# 2014-02-24 19:45:00  41.884016 -87.701143
#
#                                                      LOCATION
# CRASH_DATE
# 2013-03-03 16:48:00  POINT (-87.708743641643 41.975856915535)
# 2013-06-01 20:29:00  POINT (-87.689968732521 42.005144534455)
# 2014-01-18 18:14:00  POINT (-87.638756189808 41.885609917063)
# 2014-01-21 07:40:00  POINT (-87.561946030143 41.760710194223)
# 2014-02-24 19:45:00  POINT (-87.701142757538 41.884016475152)
#
# [5 rows x 48 columns]

# %%
# filter out years 2013--2017
data = data[data.index.year>=2018]

# %%
data.columns
# Out:
# Index(['CRASH_RECORD_ID', 'RD_NO', 'CRASH_DATE_EST_I', 'POSTED_SPEED_LIMIT',
#        'TRAFFIC_CONTROL_DEVICE', 'DEVICE_CONDITION', 'WEATHER_CONDITION',
#        'LIGHTING_CONDITION', 'FIRST_CRASH_TYPE', 'TRAFFICWAY_TYPE', 'LANE_CNT',
#        'ALIGNMENT', 'ROADWAY_SURFACE_COND', 'ROAD_DEFECT', 'REPORT_TYPE',
#        'CRASH_TYPE', 'INTERSECTION_RELATED_I', 'NOT_RIGHT_OF_WAY_I',
#        'HIT_AND_RUN_I', 'DAMAGE', 'DATE_POLICE_NOTIFIED',
#        'PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE', 'STREET_NO',
#        'STREET_DIRECTION', 'STREET_NAME', 'BEAT_OF_OCCURRENCE',
#        'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I',
#        'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I', 'NUM_UNITS',
#        'MOST_SEVERE_INJURY', 'INJURIES_TOTAL', 'INJURIES_FATAL',
#        'INJURIES_INCAPACITATING', 'INJURIES_NON_INCAPACITATING',
#        'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION',
#        'INJURIES_UNKNOWN', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH',
#        'LATITUDE', 'LONGITUDE', 'LOCATION'],
#       dtype='object')

# %% [markdown]
# ## How have the weekly number of crashes changed over time?

# %%
data.resample('W').CRASH_RECORD_ID.count().plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='CRASH_DATE'>

# %% [markdown]
# ## How has the injury rate changed over time?

# %%
# INJURIES = 1 if the crash involves injuries
data['INJURIES'] = (data.INJURIES_TOTAL>=1).astype(int) 
data.INJURIES
# Out:
# CRASH_DATE
# 2018-01-01 00:00:00    0
# 2018-01-01 00:00:00    0
# 2018-01-01 00:00:00    0
# 2018-01-01 00:05:00    0
# 2018-01-01 00:07:00    0
#                       ..
# 2022-09-11 00:53:00    0
# 2022-09-11 00:54:00    1
# 2022-09-11 01:25:00    0
# 2022-09-11 02:10:00    0
# 2022-09-11 03:23:00    0
# Name: INJURIES, Length: 511500, dtype: int32

# %%
data.groupby('INJURIES').resample('W').CRASH_RECORD_ID.count().unstack(level=0).plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='CRASH_DATE'>

# %%
# number of crashes that involve injuries
n_injuries = data[data.INJURIES==1].resample('W').CRASH_RECORD_ID.count()
n_injuries
# Out:
# CRASH_DATE
# 2018-01-07    331
# 2018-01-14    304
# 2018-01-21    316
# 2018-01-28    285
# 2018-02-04    261
#              ...
# 2022-08-14    285
# 2022-08-21    330
# 2022-08-28    311
# 2022-09-04    355
# 2022-09-11    257
# Freq: W-SUN, Name: CRASH_RECORD_ID, Length: 245, dtype: int64

# %%
# total number 
n_total = data.resample('W').CRASH_RECORD_ID.count()
n_total
# Out:
# CRASH_DATE
# 2018-01-07    2445
# 2018-01-14    2075
# 2018-01-21    2243
# 2018-01-28    1992
# 2018-02-04    2012
#               ...
# 2022-08-14    1966
# 2022-08-21    2046
# 2022-08-28    2141
# 2022-09-04    2246
# 2022-09-11    1587
# Freq: W-SUN, Name: CRASH_RECORD_ID, Length: 245, dtype: int64

# %%
# percentage of crashes that invole injuries 
pct_weekly_injuries = 100*n_injuries/n_total
pct_weekly_injuries.plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='CRASH_DATE'>

# %% [markdown]
# ## How does the injury rate change through the week?

# %%
table = data.pivot_table(values='CRASH_RECORD_ID', index=data.index.dayofweek, columns='INJURIES',aggfunc='count')
table['total'] = table.sum(axis=1)
table['pct_injuries'] = 100*table[1]/table['total']
table.index = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']
table
# Out:
# INJURIES      0      1  total  pct_injuries
# Mon       60825  10083  70908     14.219834
# Tue       61941  10366  72307     14.336095
# Wed       61292  10469  71761     14.588704
# Thu       62681  10597  73278     14.461366
# Fri       71251  11784  83035     14.191606
# Sat       65092  11209  76301     14.690502
# Sun       54125   9785  63910     15.310593

# %%
table['pct_injuries'].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Plot daily crashes histogram

# %%
data.resample('D').CRASH_RECORD_ID.count().hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## How do injuries vary with first crash type?

# %%
table = data.pivot_table(values='CRASH_RECORD_ID',index = 'FIRST_CRASH_TYPE', columns='INJURIES',aggfunc='count')
table['total'] = table.sum(axis=1)
table['pct_injuries'] = 100*table[1]/table['total']
table
# Out:
# INJURIES                           0      1   total  pct_injuries
# FIRST_CRASH_TYPE
# ANGLE                          42589  12877   55466     23.216024
# ANIMAL                           335     23     358      6.424581
# FIXED OBJECT                   21454   4543   25997     17.475093
# HEAD ON                         2939   1411    4350     32.436782
# OTHER NONCOLLISION              1398    278    1676     16.587112
# OTHER OBJECT                    4768    626    5394     11.605488
# OVERTURNED                       195    145     340     42.647059
# PARKED MOTOR VEHICLE          116610   4539  121149      3.746626
# PEDALCYCLIST                    2275   5623    7898     71.195239
# PEDESTRIAN                      1511  10834   12345     87.760227
# REAR END                       96242  15521  111763     13.887422
# REAR TO FRONT                   4986    231    5217      4.427832
# REAR TO REAR                    1116     16    1132      1.413428
# REAR TO SIDE                    2891    208    3099      6.711843
# SIDESWIPE OPPOSITE DIRECTION    6366    805    7171     11.225770
# SIDESWIPE SAME DIRECTION       70709   4140   74849      5.531136
# TRAIN                             18     13      31     41.935484
# TURNING                        60805  12460   73265     17.006756

# %%
table.pct_injuries.plot.bar(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='FIRST_CRASH_TYPE'>

# %% [markdown]
# ## Are injuries more likely in different locations?

# %%
mask = (data.LATITUDE!= 0) & (data.LONGITUDE!=0)
data[mask & (data.INJURIES==1)].plot.scatter(x='LONGITUDE', y ='LATITUDE', figsize=(7,7), s=0.1, alpha=0.5)
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %%
data[mask & (data.INJURIES==1)].plot.hexbin(x='LONGITUDE', y ='LATITUDE', gridsize=20,  figsize=(7,7),cmap='Reds')
# Out:
# <AxesSubplot:xlabel='LONGITUDE', ylabel='LATITUDE'>

# %% [markdown]
# ## Area plot

# %%
# weekly number of crashes
data.resample('W').CRASH_RECORD_ID.count().plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='CRASH_DATE'>

# %%
# weekly number of crashes by crash type
data.groupby('FIRST_CRASH_TYPE').resample('W').CRASH_RECORD_ID.count().unstack(level=0).plot(figsize=(15,7),legend=False)
# Out:
# <AxesSubplot:xlabel='CRASH_DATE'>

# %%
# the plots are stacked
data.groupby('FIRST_CRASH_TYPE').resample('W').CRASH_RECORD_ID.count().unstack(level=0).plot.area(figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='CRASH_DATE'>

# %% [markdown]
# ## Advanced plot

# %% [markdown]
# Pandas uses the `matplotlib` library

# %%
import matplotlib.pyplot as plt

# %%
# weekly number of crashes by injury status (0=no, 1=yes)
weekly = data.groupby('INJURIES').resample('W').CRASH_RECORD_ID.count().unstack(level=0)
weekly
# Out:
# INJURIES       0    1
# CRASH_DATE
# 2018-01-07  2114  331
# 2018-01-14  1771  304
# 2018-01-21  1927  316
# 2018-01-28  1707  285
# 2018-02-04  1751  261
# ...          ...  ...
# 2022-08-14  1681  285
# 2022-08-21  1716  330
# 2022-08-28  1830  311
# 2022-09-04  1891  355
# 2022-09-11  1330  257
#
# [245 rows x 2 columns]

# %%
# create figure and axis
fig, axis = plt.subplots(figsize=(15,5))
# plot weekly dataframe
weekly.plot(ax=axis)
# change x-axis label
axis.set_xlabel('date', fontsize=15)
# add y-axis label
axis.set_ylabel('weekly number of crashes', fontsize=15)
# add title
axis.set_title('Number of traffic crashes per week', fontsize=20)
# modify the legend
axis.legend(labels=['no','yes'], fontsize=15, loc = 'upper left',title='injuries?', title_fontsize=18)
# add grid lines
axis.grid(True)

# %%
# create figure and axis
fig, axis = plt.subplots(1,2,figsize=(15,5))
# plot weekly dataframe
weekly[0].plot(ax=axis[0])
weekly[1].plot(ax=axis[1],color='red')
# change x-axis labels
axis[0].set_xlabel('date', fontsize=15)
axis[1].set_xlabel('date', fontsize=15)
# set titles
axis[0].set_title('injuries = 0')
axis[1].set_title('injuries = 1')


fig.suptitle('Number of traffic crashes per week', fontsize=20)
axis[0].grid(True)
axis[1].grid(True)

# %%
# create figure and axis
fig, axis = plt.subplots(figsize=(15,5))
# create a twin axis sharing the x-axis.
axis2 = axis.twinx()
# plot weekly dataframe (injuries=0)
weekly[0].plot(ax=axis)
# plot weekly dataframe (injuries=1)
weekly[1].plot(ax=axis2,color='C1')
# change x-axis labels
axis.set_xlabel('date', fontsize=15)
# add y-axis label
axis.set_ylabel('injuries=0', fontsize=15)
axis2.set_ylabel('injuries=1', fontsize=15)
# add title
axis.set_title('Number of traffic crashes per week', fontsize=20)
# add legend
fig.legend(labels=['no','yes'], fontsize=15, loc = 'upper left',title='injuries?', title_fontsize=18)
# grid lines
axis.grid(True)
