# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # k-Nearest Neighbors (kNN)

# %% [markdown]
# k-Nearest neighbor (kNN) is an extremely simple yet surprisingly effective method for classification.
# The only things it requires are:
#
# - Some notion of distance (Euclidean distance is the most common choice).
# - An assumption that points that are close to one another are similar.

# %% [markdown]
# Classification is computed from a simple majority vote of the nearest neighbors of each point: a new point is assigned the  class which has the most representatives within the nearest neighbors of the point.

# %% [markdown]
# ![knn](png_to_gif.gif "segment")

# %% [markdown]
# kNN appeal stems from the fact that
#
# - its decision surfaces are nonlinear,
# - there is only a single integer parameter `n_neighbors`, and
# - the expected quality of predictions improves automatically as the amount of training data increases.

# %% [markdown]
# <div class="admonition note alert alert-info">
# <p class="first admonition-title" style="font-weight: bold;">Note (from the scikit learn user guide)</p>
# <p>
# The basic nearest neighbors classification uses uniform weights: that is, the value assigned to a new point is computed from a simple majority vote of the nearest neighbors.
# Under some circumstances, it is better to weight the neighbors such that nearer neighbors contribute more to the fit.
# This can be accomplished through the <tt>weights</tt> keyword.
#     The default value, <tt>weights = 'uniform'</tt>, assigns uniform weights to each neighbor.
#     <tt>weights = 'distance'</tt> assigns weights proportional to the inverse of the distance from the query point. Alternatively, a user-defined function of the distance can be supplied to compute the weights.
# </p>
# </div>

# %% [markdown]
# ## Nearest Neighbors Classification Examples

# %%
from sklearn.neighbors import KNeighborsClassifier
from matplotlib.colors import ListedColormap
from sklearn import datasets

# %% [markdown]
# Sample usage of Nearest Neighbors classification.
# We will plot the decision boundaries for each class.
#
# - [The iris dataset](#1.-The-iris-dataset)
# - [Three-blobs dataset](#2.-Three-blobs-dataset)
# - [Two-moons dataset](#3.-Two-moons-dataset)

# %% [markdown]
# ## 1. The iris dataset

# %%
'import the iris dataset'

iris = datasets.load_iris()
# we only take the first two features: sepal length and sepal width
X = iris.data[:, :2]
y = iris.target

# %%
'plot the dataset'
plt.figure(figsize=(10,5))
for i in range(3):
    plt.scatter(X[y==i,0], X[y==i,1], c = colors[i], label='class '+str(i), s=75)
    
plt.xlabel('sepal length', fontsize=15)
plt.ylabel('sepal width', fontsize=15)
plt.title('The iris dataset', fontsize=20)
plt.legend()

# %%
# mesh grid
h = .02
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# %%
'fit a knn model (with uniform weights)'
n_neighbors = 15
knn_clf = KNeighborsClassifier(n_neighbors, weights='uniform')
knn_clf.fit(X, y)

# evaluate classifier at all mesh grid points
Z = knn_clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
# Put the result into a color plot
plt.figure(figsize=(10,5))
custom_cmap = ListedColormap(['#9898ff','#fafab0','#a0faa0'])
plt.contourf(xx, yy, Z, cmap=custom_cmap)

# dataset
for i in range(3):
    plt.scatter(X[y==i,0], X[y==i,1], c = colors[i], label='class '+str(i), s=75)
    
plt.xlabel('sepal length', fontsize=15)
plt.ylabel('sepal width', fontsize=15)

plt.suptitle('The iris dataset', fontsize=20)
plt.title("n_neighbors=15, weights='uniform'",fontsize=15)

plt.legend()

# %%
'fit a knn model (with distance weights)'
n_neighbors = 15
knn_clf = KNeighborsClassifier(n_neighbors, weights='distance')
knn_clf.fit(X, y)

# evaluate classifier at all mesh grid points
Z = knn_clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
# Put the result into a color plot
plt.figure(figsize=(10,5))
custom_cmap = ListedColormap(['#9898ff','#fafab0','#a0faa0'])
plt.contourf(xx, yy, Z, cmap=custom_cmap)

# dataset
for i in range(3):
    plt.scatter(X[y==i,0], X[y==i,1], c = colors[i], label='class '+str(i), s=75)
    
plt.xlabel('sepal length', fontsize=15)
plt.ylabel('sepal width', fontsize=15)

plt.suptitle('The iris dataset', fontsize=20)
plt.title("n_neighbors=15, weights='distance'",fontsize=15)

plt.legend()

# %% [markdown]
# ## 2. Three-blobs dataset

# %%
from sklearn.datasets import make_blobs
X,y = make_blobs(n_samples =200,
                 centers = 3,
                 cluster_std = 2.)

# %%
'plot dataset'
plt.figure(figsize=(10,5))
for i in range(3):
    plt.scatter(X[y==i,0], X[y==i,1], c = colors[i], label='class '+str(i), s=75)
    
plt.xlabel('feature #1', fontsize=15)
plt.ylabel('feature #2', fontsize=15)
plt.title('Three-blobs dataset', fontsize=20)
plt.legend()

# %%
# mesh grid
n_points = 100
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, n_points),
                     np.linspace(y_min, y_max, n_points))

# %%
'fit a knn model (with uniform weights)'
n_neighbors = 15
knn_clf = KNeighborsClassifier(n_neighbors, weights='uniform')
knn_clf.fit(X, y)

# evaluate classifier at all mesh grid points
Z = knn_clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
# Put the result into a color plot
plt.figure(figsize=(10,5))
custom_cmap = ListedColormap(['#9898ff','#fafab0','#a0faa0'])
plt.contourf(xx, yy, Z, cmap=custom_cmap)

# dataset
for i in range(3):
    plt.scatter(X[y==i,0], X[y==i,1], c = colors[i], label='class '+str(i), s=75)
    
plt.xlabel('feature #1', fontsize=15)
plt.ylabel('feature #2', fontsize=15)

plt.suptitle('Three-blobs dataset', fontsize=20)
plt.title("n_neighbors=15, weights='uniform'",fontsize=15)

plt.legend()

# %% [markdown]
# ## 3. Two-moons dataset

# %%
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=100, noise=0.15, random_state=42)

# %%
from sklearn.datasets import make_blobs
X,y = make_blobs(n_samples =200,
                 centers = 3,
                 cluster_std = 2.)

# %%
theta = np.linspace(0, 2*np.pi, 100)

# %%
plt.figure(figsize=(10,5))
for i in range(3):
    plt.scatter(X[y==i,0], X[y==i,1], c = colors[i], label='cluster '+str(i), s=75, alpha=0.8)
plt.legend()

#new_x1 = np.array([0,4]) # 3:[0,4]

#plt.scatter(new_x1[0],new_x1[1],c='k', s=75)
#plt.annotate('new point', 
#             xy = new_x1,
#             xytext = new_x1-[0,4],
#             fontsize=15,
#             arrowprops = dict(arrowstyle="->"))


#r = np.sort(np.linalg.norm(X-new_x1,axis=1))[9]

#x1 = new_x1[0] + r*np.cos(theta)
#x2 = new_x1[1] + r*np.sin(theta)
#plt.plot(x1,x2,'k')

#plt.annotate('10 nearest neighbors',
#             xy = new_x1,
#             xytext = [0,-1], # 3:[0,-1]
#             fontsize=15)

#plt.scatter(new_x1[0],new_x1[1],c='C0',s=75, alpha=0.8)

#plt.savefig('img13.png')

# %%
from PIL import Image
import glob

# %%
frames = []
imgs = ['img'+str(i)+'.png' for i in range(1,14)]
for i in imgs:
    frames.append(Image.open(i))

frames[0].save('png_to_gif.gif',
               format='GIF',
               append_images=frames[1:],
               save_all=True,
               duration=1000,
               loop=0)

#frames[0].save('png_to_gif.gif', format='GIF',
#               append_images=frames[1:],
#               save_all=True,
#               duration=300, loop=0)

# %%
frames[0]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x360 at 0x273A235DC40>
