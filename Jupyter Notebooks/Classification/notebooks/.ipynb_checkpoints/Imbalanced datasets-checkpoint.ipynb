# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Imbalanced datasets

# %% [markdown]
# An imbalanced dataset has one class with many more examples than the other. This makes it tricky because models tend to focus on the majority class and may ignore the minority class, which is often the more important one, like fraud detection or diagnosing rare diseases.

# %% [markdown]
# Let's look at an example.

# %% [markdown]
# ## 1. The Adult Census Income Dataset

# %% [markdown]
# For our example, we'll use the Adult Census Income dataset. This dataset contains information about people's age, education, work, and more. The goal is to predict whether a person earns more than $50,000 a year based on their demographic and work-related data.

# %%
path = 'https://raw.githubusercontent.com/um-perez-alvaro/Data-Science-Practice/master/Data/adult_census.csv'
df = pd.read_csv(path)
df
# Out:
#        age         workclass    fnlwgt  education  education-num  \
# 0        2         State-gov   77516.0  Bachelors           13.0
# 1        3  Self-emp-not-inc   83311.0  Bachelors           13.0
# 2        2           Private  215646.0    HS-grad            9.0
# 3        3           Private  234721.0       11th            7.0
# 4        1           Private  338409.0  Bachelors           13.0
# ...    ...               ...       ...        ...            ...
# 38319    2           Private  215419.0  Bachelors           13.0
# 38320    4               NaN  321403.0    HS-grad            9.0
# 38321    2           Private  374983.0  Bachelors           13.0
# 38322    2           Private   83891.0  Bachelors           13.0
# 38323    1      Self-emp-inc  182148.0  Bachelors           13.0
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# 2                Divorced  Handlers-cleaners   Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners         Husband
# 4      Married-civ-spouse     Prof-specialty            Wife
# ...                   ...                ...             ...
# 38319            Divorced     Prof-specialty   Not-in-family
# 38320             Widowed                NaN  Other-relative
# 38321  Married-civ-spouse     Prof-specialty         Husband
# 38322            Divorced       Adm-clerical       Own-child
# 38323  Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capitalgain  capitalloss  hoursperweek  \
# 0                   White    Male            1            0             2
# 1                   White    Male            0            0             0
# 2                   White    Male            0            0             2
# 3                   Black    Male            0            0             2
# 4                   Black  Female            0            0             2
# ...                   ...     ...          ...          ...           ...
# 38319               White  Female            0            0             2
# 38320               Black    Male            0            0             2
# 38321               White    Male            0            0             3
# 38322  Asian-Pac-Islander    Male            2            0             2
# 38323               White    Male            0            0             3
#
#       native-country  label
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4               Cuba  <=50K
# ...              ...    ...
# 38319  United-States  <=50K
# 38320  United-States  <=50K
# 38321  United-States  <=50K
# 38322  United-States  <=50K
# 38323  United-States   >50K
#
# [38324 rows x 15 columns]

# %% [markdown]
# To check if the dataset is imbalanced, we can look at the distribution of the target variable (whether someone earns more than $50K).

# %%
df.label.value_counts()
# Out:
# label
# <=50K    37155
# >50K      1169
# Name: count, dtype: int64

# %% [markdown]
# The results show that 37,155 people earn <=50K (97%), while only 1,169 earn >50K (3%). This large difference confirms that the dataset is heavily imbalanced, with far more people in the <=50K class.

# %% [markdown]
# ## 2. When Accuracy Misleads

# %% [markdown]
# Let's put together a simple classification pipeline. Nothing fancy. We'll impute missing values, scale the numerical features, and one-hot encode the categorical features. After that, we'll add my favorite model: [the dummy classifier](https://scikit-learn.org/stable/modules/model_evaluation.html#dummy-estimators).

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures, OneHotEncoder
from sklearn.impute import SimpleImputer

from sklearn.dummy import DummyClassifier

# %%
num_features = ['age','fnlwgt','education-num','capitalgain','capitalloss','hoursperweek']
cat_features = ['workclass','marital-status','occupation','relationship','race','sex','native-country']

cat_pipeline = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('encoder',OneHotEncoder(handle_unknown='ignore'))
])

num_pipeline = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',MinMaxScaler())
])

feature_processor = ColumnTransformer(transformers=[
    ('num',num_pipeline,num_features),
    ('cat',cat_pipeline,cat_features)
])

pipe_dummy_clf = Pipeline(steps=[
    ('processor', feature_processor),
    ('clf',DummyClassifier(strategy='most_frequent'))
])
pipe_dummy_clf
# Out:
# Pipeline(steps=[('processor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['age', 'fnlwgt',
#                                                    'education-num',
#                                                    'capitalgain', 'capitalloss',
#                                                    'hoursperweek']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['workclass',
#                                                    'marital-status',
#                                                    'occupation', 'relationship',
#                                                    'race', 'sex',
#                                                    'native-country'])])),
#                 ('clf', DummyClassifier())])

# %% [markdown]
# The dummy classifier is, as the name suggests, 'dummy.' It always predicts the majority class, which in our case is `<=50K`.

# %% [markdown]
# Let's now evaluate our amazing model!

# %%
# Feature matrix X, target vector y
X = df.drop(['education', 'label'], axis=1) # Dropping 'education' because 'num-education' has the same info
y = df['label']

# %%
# train-test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
pipe_dummy_clf.fit(X_train,y_train)
y_test_pred = pipe_dummy_clf.predict(X_test)
y_test_pred
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype='<U5')

# %% [markdown]
# Let's check the accuracy of our model on the test set.

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_test_pred)
# Out:
# 0.972027972027972

# %% [markdown]
# Wow! 97% of the predictions are correct.
# Not too bad, right?
# But hold on a second.
# There's a big problem here.
# Our dataset is very imbalanced.
# The model is just predicting the majority class (`<=50K`) all the time.
# That’s why the accuracy looks good, but it’s not actually telling us how well the model is doing with the minority class (`>50K`).

# %% [markdown]
# So be careful when using evaluation metrics like accuracy on an imbalanced dataset. Your model might not be as good as it seems!

# %% [markdown]
# ## 2. A Classification Pipeline

# %% [markdown]
# Back to more serious business. Let's replace the dummy classifier with a decision tree.

# %%
from sklearn.tree import DecisionTreeClassifier
pipe_tree_clf = Pipeline(steps=[
    ('processor', feature_processor),
    ('clf',DecisionTreeClassifier())
])
pipe_tree_clf
# Out:
# Pipeline(steps=[('processor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['age', 'fnlwgt',
#                                                    'education-num',
#                                                    'capitalgain', 'capitalloss',
#                                                    'hoursperweek']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['workclass',
#                                                    'marital-status',
#                                                    'occupation', 'relationship',
#                                                    'race', 'sex',
#                                                    'native-country'])])),
#                 ('clf', DecisionTreeClassifier())])

# %% [markdown]
# We'll run a quick grid search to fine-tune the depth of the decision tree.
# First, we need to pick the right evaluation metric.
# This depends on the specific goals and problem.
#
# Instead of using accuracy, which we know isn't a good choice for imbalanced data, we'll use [balanced accuracy](https://scikit-learn.org/stable/modules/model_evaluation.html#balanced-accuracy-score)
# . Balanced accuracy is better for imbalanced data because it takes into account both classe
# . It's the average of sensitivity (true positive rate) and specificity (true negative rate."

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import balanced_accuracy_score, ConfusionMatrixDisplay

# %%
# Define the parameter grid for the number of neighbors (from 5 to 30, for example)
param_grid = {
    'clf__max_depth': range(3,11) 
}

# Set up the grid search using balanced accuracy as the scoring metric
grid_search = GridSearchCV(pipe_tree_clf, param_grid, scoring='balanced_accuracy', cv=5)

# Run the grid search on the training data
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('processor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['age',
#                                                                           'fnlwgt',
#                                                                           'education-num',
#                                                                           'capitalgain',
#                                                                           'capitalloss',
#                                                                           'hoursperweek']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['workclass',
#                                                                           'marital-status',
#                                                                           'occupation',
#                                                                           'relationship',
#                                                                           'race',
#                                                                           'sex',
#                                                                           'native-country'])])),
#                                        ('clf', DecisionTreeClassifier())]),
#              param_grid={'clf__max_depth': range(3, 11)},
#              scoring='balanced_accuracy')

# %%
best_pipe_clf = grid_search.best_estimator_
y_test_pred = best_pipe_clf.predict(X_test)

# %%
# accuracy (we know it could be misleading)
accuracy_score(y_test,y_test_pred)
# Out:
# 0.9724454649827784

# %%
# confusion matrix
ConfusionMatrixDisplay.from_estimator(best_pipe_clf,X_test,y_test)

# %% [markdown]
# The model hardly predicts the minority class. This is reflected in the lower balanced accuracy score.

# %%
balanced_accuracy_score(y_test_pred,y_test)
# Out:
# 0.7897287190454807

# %% [markdown]
# The imbalance is causing the model to focus too much on the majority class. What can we do to compensate for this?
# As far as I know, there are three strategies:
#
# 1. Some scikit-learn models have a `class_weight` parameter, which you can use to give more importance to the minority class and help the model focus on it.
# 2. You can also handle imbalance by oversampling the minority class (adding more examples) or undersampling the majority class (removing examples). Another popular method is [SMOTE](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.SMOTE.html) (Synthetic Minority Over-sampling Technique), which creates synthetic samples of the minority class to balance the dataset.
# 3.  You can also adjust the classification threshold.
#
# We'll focus on the third strategy: adjusting the classification threshold.

# %% [markdown]
# ## 3. Adjusting the classification threshold.

# %% [markdown]
# We know we can manually change the classification threshold. We'll use this to see if we can improve the results for the minority class. But before that, we need to tune the hyperparameters of our model. Since we're going to change the classification threshold later, we need to do the grid search using a 'threshold-independent' evaluation metric. We've seen two examples: AUC (Area Under the Curve) and AP (Average Precision).

# %%
# Define the parameter grid for the decision tree
param_grid = {
    'clf__max_depth': range(3, 11),  
}

# Set up the grid search using AP (Average Precision) as the scoring metric
grid_search = GridSearchCV(pipe_tree_clf, param_grid, scoring='average_precision', cv=5)

# Run the grid search on the training data
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 89, in _cached_call
#     result, _ = _get_response_values(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_response.py", line 204, in _get_response_values
#     raise ValueError(
# ValueError: pos_label=1 is not a valid label: It should be one of ['<=50K' '>50K']
#
#   warnings.warn(
# C:\Users\javier.perez-alvaro\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('processor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['age',
#                                                                           'fnlwgt',
#                                                                           'education-num',
#                                                                           'capitalgain',
#                                                                           'capitalloss',
#                                                                           'hoursperweek']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['workclass',
#                                                                           'marital-status',
#                                                                           'occupation',
#                                                                           'relationship',
#                                                                           'race',
#                                                                           'sex',
#                                                                           'native-country'])])),
#                                        ('clf', DecisionTreeClassifier())]),
#              param_grid={'clf__max_depth': range(3, 11)},
#              scoring='average_precision')

# %% [markdown]
# You'll run into a lot of errors because the `average_precision` scoring metric expects the target labels to be in a numerical format, with the positive class usually being `1`. Since your labels are strings (`<=50K` and `>50K`), you need to specify which one is the positive class.

# %%
# Define a custom scorer using 'average_precision' and specify the positive class
from sklearn.metrics import make_scorer, average_precision_score
ap_scorer = make_scorer(average_precision_score, pos_label='>50K')

# Set up the grid search using the custom AP scorer
grid_search = GridSearchCV(pipe_tree_clf, param_grid, scoring='average_precision', cv=5)

# Run the grid search on the training data
grid_search.fit(X_train, y_train.map({'<=50K':0,'>50K':1}))
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('processor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['age',
#                                                                           'fnlwgt',
#                                                                           'education-num',
#                                                                           'capitalgain',
#                                                                           'capitalloss',
#                                                                           'hoursperweek']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['workclass',
#                                                                           'marital-status',
#                                                                           'occupation',
#                                                                           'relationship',
#                                                                           'race',
#                                                                           'sex',
#                                                                           'native-country'])])),
#                                        ('clf', DecisionTreeClassifier())]),
#              param_grid={'clf__max_depth': range(3, 11)},
#              scoring='average_precision')

# %%
best_pipe_clf = grid_search.best_estimator_

# %% [markdown]
# Now, for the second step, we want to maximize our chosen evaluation metric—balanced accuracy in this case—based on the classification threshold. Depending on your application, you might want to maximize other metrics, like recall, precision, or something else. But the idea remains the same: we'll adjust the classification threshold to get the best performance for the metric we care about.

# %%
# balanced_accuracy as a function of threshold

proba = best_pipe_clf.predict_proba(X_test)[:,1]
thresholds = np.linspace(0,1,100) # 100 evenly spaced points on [0,1]

balanced_accuracies = []
for threshold in thresholds:
    y_test_pred = np.zeros(len(y_test)) # vector of all zeros
    y_test_pred[proba > threshold]=1
    balanced_accuracies.append(balanced_accuracy_score(y_test.map({'<=50K':0,'>50K':1}),
                                                       y_test_pred
                                                      )
                              )

# %%
plt.plot(thresholds,balanced_accuracies)

# %% [markdown]
# Balanced accuracy is maximized at a very low threshold.

# %%
threshold = thresholds[np.argmax(balanced_accuracies)]
threshold
# Out:
# 0.04040404040404041

# %% [markdown]
# Now, let's use this threshold and test our model on the test set.

# %%
y_test_pred = np.zeros(len(y_test)) # vector of all zeros
y_test_pred[proba > threshold]=1
ConfusionMatrixDisplay.from_predictions(y_test.map({'<=50K':0,'>50K':1}),
                                        y_test_pred
                                        )

# %% [markdown]
# Now the model is finally predicting the minority class! Of course, we pay a price with a higher false positive rate, but that's a small trade-off if predicting the minority class is what matters most.
