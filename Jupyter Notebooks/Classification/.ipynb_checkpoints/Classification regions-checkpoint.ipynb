# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import plot_decision_boundary

# %%
from matplotlib.colors import ListedColormap
def plot_decision_boundary2(clf, X, y, labels, transformation = None):
    '''Function for plotting the classification boundaries.
    
    INPUTS:
    
        clf: a sklearn classifier
        
        X: feature matrix
        
        y: target vector ({0,1} or {0,1,2})
        
        labels: vector with the class labels
    '''
    # get axes names
    axes_names = X.columns
    # get axes limits
    axes=[X.iloc[:,0].min()-0.5, X.iloc[:,0].max()+0.5, X.iloc[:,1].min()-0.5, X.iloc[:,1].max()+0.5]
    # create a 100x100 meshgrid
    x1s = np.linspace(axes[0], axes[1], 100)
    x2s = np.linspace(axes[2], axes[3], 100)
    x1, x2 = np.meshgrid(x1s, x2s) 
    X_new = np.c_[x1.ravel(), x2.ravel()]
    # make a prediction at each point of the mesh grid
    if transformation == None:
        y_pred = clf.predict(X_new).reshape(x1.shape)
    else:
        X_new_transformed = transformation.transform(X_new)
        y_pred = clf.predict(X_new_transformed).reshape(x1.shape)
    custom_cmap = ListedColormap(['#fafab0','#9898ff','#a0faa0']) # some nice colors
    # contour map
    colors = ['blue','red','green']
    plt.contourf(x1, x2, y_pred, alpha=0.3, cmap=custom_cmap)
    for i in range(len(labels)):
        plt.plot(X.loc[y==i,axes_names[0]],X.loc[y==i,axes_names[1]], 'o', color=colors[i], label = labels[i])

    'set axes'
    plt.axis(axes)
    'axes labels'
    plt.xlabel("Petal length", fontsize=14)
    plt.ylabel("Petal width", fontsize=14)
    'plot legend'
    plt.legend(loc="lower right", fontsize=14)

# %% [markdown]
# # 1. Binary Classification Algorithms

# %% [markdown]
# - Linear Models (regression and Logistic regression)
# - Nearest Neighbor Classifiers

# %% [markdown]
# ## Load the data

# %%
url = 'https://raw.githubusercontent.com/um-perez-alvaro/lin-regress/master/iris.data'
iris = pd.read_csv(url, names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width','species'])
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# **goal:** predict if species is setosa or not

# %%
def is_setosa(species):
    if species == 'Iris-setosa':
        return 'yes'
    else:
        return 'no'

iris['is_setosa'] = iris.species.apply(is_setosa)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species is_setosa
# 0           5.1          3.5           1.4          0.2  Iris-setosa       yes
# 1           4.9          3.0           1.4          0.2  Iris-setosa       yes
# 2           4.7          3.2           1.3          0.2  Iris-setosa       yes
# 3           4.6          3.1           1.5          0.2  Iris-setosa       yes
# 4           5.0          3.6           1.4          0.2  Iris-setosa       yes

# %% [markdown]
# In this example, we'll use only two features (petal_length and petal_width).

# %%
iris.drop(['sepal_length','sepal_width','species'],axis=1,inplace=True) 
iris.head() # bidimensional dataset
# Out:
#    petal_length  petal_width is_setosa
# 0           1.4          0.2       yes
# 1           1.4          0.2       yes
# 2           1.3          0.2       yes
# 3           1.5          0.2       yes
# 4           1.4          0.2       yes

# %%
# plot the dataset
fig, ax = plt.subplots(figsize=(12,5))

iris.loc[iris.is_setosa=='yes',:].plot.scatter(x='petal_length',y='petal_width', c='red', ax=ax, label='setosa') # setosa
iris.loc[iris.is_setosa=='no',:].plot.scatter(x='petal_length',y='petal_width', c='blue', ax=ax, label='non-setosa') # non-setosa

# %% [markdown]
# ## 1.1. Linear Regression

# %% [markdown]
# This classifier first converts the target values into {-1, 1} and then treats the problem as a regression task.

# %%
X = iris[['petal_length','petal_width']]
y = iris.is_setosa

# %%
from sklearn.linear_model import RidgeClassifier
linear_clf = RidgeClassifier() # import classifier
linear_clf.fit(X,y) # train the classifier
# Out:
# RidgeClassifier()

# %%
plt.figure(figsize=(12,5))
plot_decision_boundary2(linear_clf, X, y,labels=['setosa','non-setosa'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-c8490e96818f> in <module>
#       1 plt.figure(figsize=(12,5))
# ----> 2 plot_decision_boundary2(linear_clf, X, y,labels=['setosa','non-setosa'])
#
# <ipython-input-1-b760e06a3c7e> in plot_decision_boundary2(clf, X, y, labels, transformation)
#      31     # contour map
#      32     colors = ['blue','red','green']
# ---> 33     plt.contourf(x1, x2, y_pred, alpha=0.3, cmap=custom_cmap)
#      34     for i in range(len(labels)):
#      35         plt.plot(X.loc[y==i,axes_names[0]],X.loc[y==i,axes_names[1]], 'o', color=colors[i], label = labels[i])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in contourf(data, *args, **kwargs)
#    2495 @docstring.copy(Axes.contourf)
#    2496 def contourf(*args, data=None, **kwargs):
# -> 2497     __ret = gca().contourf(
#    2498         *args, **({"data": data} if data is not None else {}),
#    2499         **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in contourf(self, *args, **kwargs)
#    6343     def contourf(self, *args, **kwargs):
#    6344         kwargs['filled'] = True
# -> 6345         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6346         self._request_autoscale_view()
#    6347         return contours
#
# ~\Anaconda3\lib\site-packages\matplotlib\contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     820         self._transform = kwargs.pop('transform', None)
#     821
# --> 822         kwargs = self._process_args(*args, **kwargs)
#     823         self._process_levels()
#     824
#
# ~\Anaconda3\lib\site-packages\matplotlib\contour.py in _process_args(self, *args, **kwargs)
#    1417                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1418
# -> 1419             x, y, z = self._contour_args(args, kwargs)
#    1420
#    1421             _mask = ma.getmask(z)
#
# ~\Anaconda3\lib\site-packages\matplotlib\contour.py in _contour_args(self, args, kwargs)
#    1475             args = args[1:]
#    1476         elif Nargs <= 4:
# -> 1477             x, y, z = self._check_xyz(args[:3], kwargs)
#    1478             args = args[3:]
#    1479         else:
#
# ~\Anaconda3\lib\site-packages\matplotlib\contour.py in _check_xyz(self, args, kwargs)
#    1503         x = np.asarray(x, dtype=np.float64)
#    1504         y = np.asarray(y, dtype=np.float64)
# -> 1505         z = ma.asarray(args[2], dtype=np.float64)
#    1506
#    1507         if z.ndim != 2:
#
# ~\Anaconda3\lib\site-packages\numpy\ma\core.py in asarray(a, dtype, order)
#    7846     """
#    7847     order = order or 'C'
# -> 7848     return masked_array(a, dtype=dtype, copy=False, keep_mask=True,
#    7849                         subok=False, order=order)
#    7850
#
# ~\Anaconda3\lib\site-packages\numpy\ma\core.py in __new__(cls, data, mask, dtype, copy, subok, ndmin, fill_value, keep_mask, hard_mask, shrink, order, **options)
#    2792         """
#    2793         # Process data.
# -> 2794         _data = np.array(data, dtype=dtype, copy=copy,
#    2795                          order=order, subok=True, ndmin=ndmin)
#    2796         _baseclass = getattr(data, '_baseclass', type(_data))
#
# ValueError: could not convert string to float: 'no'

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log_clf = LogisticRegression()
log_clf.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
plt.figure(figsize=(12,5))
plot_decision_boundary(log_clf, X, y, my_labels)

# %% [markdown]
# ## Support Vector Machines

# %%
from sklearn.svm import LinearSVC
linearSVC_clf = LinearSVC()
linearSVC_clf.fit(X,y)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
plt.figure(figsize=(12,5))
plot_decision_boundary(linearSVC_clf, X, y, my_labels)

# %%
from sklearn.svm import SVC
SVC_clf = SVC()
SVC_clf.fit(X,y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
plt.figure(figsize=(12,5))
plot_decision_boundary(SVC_clf, X, y, my_labels)

# %% [markdown]
# ## Nearest Neighbors Classifiers

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier(n_neighbors=5) # by default, n_neighbors = 5
knn_clf.fit(X,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
plt.figure(figsize=(12,5))
plot_decision_boundary(knn_clf, X, y, my_labels)

# %%
knn_clf = KNeighborsClassifier(n_neighbors=5, weights='distance') # by default, n_neighbors = 5
knn_clf.fit(X,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='distance')

# %%
plt.figure(figsize=(12,5))
plot_decision_boundary(knn_clf, X, y, my_labels)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
tree_clf = DecisionTreeClassifier()
tree_clf.fit(X,y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
plt.figure(figsize=(12,5))
plot_decision_boundary(tree_clf, X, y, my_labels)

# %%
from sklearn.tree import plot_tree
fig = plt.figure(figsize=(25,20))
_ = plot_tree(tree_clf, feature_names=X.columns, class_names =['non-virginica','virginica'], filled='True')

# %% [markdown]
# # Adding polynomial features

# %%
plt.figure(figsize=(12,5))
for specie in iris.species.unique():
    plt.scatter(X.loc[iris.species==specie,'petal_length'], X.loc[iris.species==specie,'petal_width'], label=specie)
    plt.legend(fontsize=20)

# %%
my_map = {'setosa':0,'versicolor':1,'virginica':0}
iris['is_versicolor'] = iris.species.map(my_map)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  is_virginica  \
# 0           5.1          3.5           1.4          0.2  setosa             0
# 1           4.9          3.0           1.4          0.2  setosa             0
# 2           4.7          3.2           1.3          0.2  setosa             0
# 3           4.6          3.1           1.5          0.2  setosa             0
# 4           5.0          3.6           1.4          0.2  setosa             0
#
#    is_versicolor
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
my_labels = ['petal_length','petal_width']
X = iris[my_labels]
y = iris.is_versicolor

# %% [markdown]
# ## Linear Models (regression, logistic regression, linearSVC)

# %%
# train regression model
from sklearn.linear_model import RidgeClassifier
clf = RidgeClassifier() # import classifier
clf.fit(X,y)
# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y, my_labels)
plt.title('Regression classification boundarier', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Regression classification boundarier')

# %%
# train logistic regression model
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression() # import classifier
clf.fit(X,y)
# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y, my_labels)
plt.title('Logistic regression classification boundarier', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Logistic regression classification boundarier')

# %%
clf = LinearSVC(max_iter=1000)
clf.fit(X,y)
# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y, my_labels)
plt.title('linearSVC classification boundary', fontsize=20)
# Out:
# Text(0.5, 1.0, 'linearSVC classification boundarier')

# %% [markdown]
# ## Nonlinear Models (Classification Trees, knn)

# %%
# train knn model
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(weights='distance') # import classifier
clf.fit(X,y)
# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y, my_labels)
plt.title('knn classification boundary', fontsize=20)
# Out:
# Text(0.5, 1.0, 'knn classification boundaries')

# %%
# train tree model
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier() # import classifier
clf.fit(X,y)
# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y, my_labels)
plt.title('tree classification boundary', fontsize=20)
# Out:
# Text(0.5, 1.0, 'tree classification boundaries')

# %% [markdown]
# ## Linear Model + polynomial features: Making linear models great again

# %%
# polynomial features
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
poly.fit(X)
X_transformed = poly.transform(X)
X_transformed.shape, X.shape
# Out:
# ((150, 6), (150, 2))

# %%
# train regression model
clf = RidgeClassifier() # import classifier
clf.fit(X_transformed,y)
# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y,my_labels,transformation=poly)
plt.title('Regression classification boundarier', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Regression classification boundarier')

# %%
# train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_transformed,y)
# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y,my_labels,transformation=poly)
plt.title('Logistic regression classification boundarier', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Logistic regression classification boundarier')

# %%
# train linearSVC
clf = LinearSVC(max_iter=2000)
clf.fit(X_transformed,y)
# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y,my_labels,transformation=poly)
plt.title('LinearSVM classification boundarier', fontsize=20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Text(0.5, 1.0, 'LinearSVM classification boundarier')

# %% [markdown]
# ## LinearSVC vs SVC

# %%
# toy dataset
from sklearn.datasets import make_moons
X,y = make_moons(n_samples=100, noise = 0.15)
X = pd.DataFrame(X,columns=['feature 1','feature 2'])
y = pd.Series(y)
X.head()
# Out:
#    feature 1  feature 2
# 0  -0.901854   0.501108
# 1   0.629036  -0.242554
# 2   0.377209   0.901765
# 3   1.366083  -0.206816
# 4  -0.023176   1.247010

# %%
# plot dataset
plt.figure(figsize=(12,5))
plt.plot(X.iloc[y==0,0],X.iloc[y==0,1], 'bo')
plt.plot(X.iloc[y==1,0],X.iloc[y==1,1], 'ro')

# %%
clf = LinearSVC()
clf.fit(X,y)

my_labels = ['0','1']

# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y, my_labels)
plt.title('linearSVC', fontsize=20)
# Out:
# Text(0.5, 1.0, 'linearSVC')

# %%
poly = PolynomialFeatures(degree=5)
poly.fit(X)
X_transformed = poly.transform(X)

clf = LinearSVC(max_iter=4000)
clf.fit(X_transformed,y)
# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y,my_labels,transformation=poly)
plt.title('LinearSVM + polynomial features', fontsize=20)
# Out:
# Text(0.5, 1.0, 'LinearSVM + polynomial features')

# %%
from sklearn.svm import SVC
clf = SVC(kernel = 'poly',degree=5, coef0=1)
clf.fit(X,y)

my_labels = ['0','1']

# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y, my_labels)
plt.title('SVC + polynomial filter', fontsize=20)
# Out:
# Text(0.5, 1.0, 'SVC + polynomial filter')

# %%
from sklearn.svm import SVC
clf = SVC(kernel = 'rbf', gamma= 5, C = 0.001)
clf.fit(X,y)

my_labels = ['0','1']

# plot dataset + decision boundary
plt.figure(figsize=(12,5))
plot_decision_boundary(clf, X, y, my_labels)
plt.title('SVC + rbf filter', fontsize=20)
# Out:
# Text(0.5, 1.0, 'SVC + rbf filter')

# %%
y.unique()
# Out:
# array([0, 1], dtype=int64)
