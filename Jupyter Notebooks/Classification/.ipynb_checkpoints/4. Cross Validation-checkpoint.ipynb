# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 4. Cross-validation for parameter tuning, model selection and feature selection

# %% [markdown]
# **Motivation:** Need a way to choose between machine learning models, and to choose hyper-parameters
# - Goal is to estimate likely performance of a model on **out-of-sample data**
#
#
# **Cross validation:**
# - Create a bunch of train/test splits, calculate the testing accuracy for each and average the result together

# %% [markdown]
# # Loading the dataset

# %%
# load the data
url = 'https://raw.githubusercontent.com/um-perez-alvaro/lin-regress/master/iris.data'
iris = pd.read_csv(url)
X = iris.iloc[:,0:4] # feature matrix
y = iris.species
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-f93e2e872c6a> in <module>
#       3 iris = pd.read_csv(url)
#       4 X = iris.iloc[:,0:4] # feature matrix
# ----> 5 y = iris.species
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'species'

# %% [markdown]
# ## Cross-validation example: parameter tuning

# %% [markdown]
# **Goal:** Select the best tuning parameters for KNN on the iris dataset

# %%
from sklearn.model_selection import cross_val_score

# %%
#1 10-fold cross-validation with k=5 for knn
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier(n_neighbors=5)
scores = cross_val_score(knn_clf,X,y,cv=10,scoring='accuracy')

# %%
print(scores)
# Out:
# [1.         0.93333333 1.         1.         0.86666667 0.93333333
#  0.93333333 1.         1.         1.        ]

# %%
# use average accuracy as an estimate of out-of-sample accuracy
scores.mean()
# Out:
# 0.9666666666666668

# %%
# search for an optimal value of k for knn
k_range = list(range(1, 31))
k_scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X, y, cv=10, scoring='accuracy')
    k_scores.append(scores.mean())

# %%
# plot the value of K for KNN (x-axis) versus the cross-validated accuracy (y-axis)
plt.plot(k_range, k_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %% [markdown]
# ## Cross-validation example: model selection

# %% [markdown]
# **Goal:** Compare the best knn model with logistic regression on the iris dataset

# %%
# 10-fold cross-validation with the best KNN model
knn_clf = KNeighborsClassifier(n_neighbors=20)
print(cross_val_score(knn_clf,X,y,cv=10,scoring='accuracy').mean())
# Out:
# 0.9800000000000001

# %%
# 10-fold cross-validation with logistic regression
from sklearn.linear_model import LogisticRegression
log_clf = LogisticRegression(max_iter=1000)
print(cross_val_score(log_clf, X, y, cv=10, scoring='accuracy').mean())
# Out:
# 0.9733333333333334

# %% [markdown]
# **Goal:** Select whether the sepal features should be included in the logistic regression model

# %%
col1 = ['petal_length','petal_width']
col2 = ['petal_length','petal_width','sepal_width']
col3 = ['petal_length','petal_width','sepal_length']

# %%
#
X = iris[col1]
y = iris.species
logreg = LogisticRegression()
print(cross_val_score(logreg, X, y, cv=10, scoring='accuracy').mean())
# Out:
# 0.96

# %%
# 
X = iris[col2]
y = iris.species
logreg = LogisticRegression()
print(cross_val_score(logreg, X, y, cv=10, scoring='accuracy').mean())
# Out:
# 0.9733333333333334

# %%
# 
X = iris[col3]
y = iris.species
logreg = LogisticRegression()
print(cross_val_score(logreg, X, y, cv=10, scoring='accuracy').mean())
# Out:
# 0.9666666666666666

# %%
# 
X = iris.iloc[:,0:4]
y = iris.species
logreg = LogisticRegression(max_iter=1000)
print(cross_val_score(logreg, X, y, cv=10, scoring='accuracy').mean())
# Out:
# 0.9733333333333334
