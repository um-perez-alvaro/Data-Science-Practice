# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Linear Regression

# %% [markdown]
# Linear regression helps us fit a line (or hyperplane in higher dimensions) to a dataset.
# There are a few reasons why we might use regression:
#
# - To create a trend line (or curve) that visually summarizes the data and highlights key insights.
# - To build a model that allows us to make precise predictions.

# %% [markdown]
# ## 1.  Linear Regression

# %% [markdown]
# Linear regression models the relationship between two variables ($x$ and $y$) by fitting a linear equation: $y = \theta_1 x + \theta_0$ to the observed data.

# %% [markdown]
# The following cell generates and plots a dataset that follows the equation $y = 2x + 1$ with a little noise.

# %%
# Generate the dataset
m = 50  # number of points
x = -1 + 2*np.random.rand(m, 1)  # m random points in the interval [-1, 1]
y = 2*x + 1 + 0.25*np.random.randn(m, 1)  # y = 2x + 1 + small random noise
plt.scatter(x, y)

# %% [markdown]
# The plot shows that $x$ and $y$ are roughly correlated: as $x$ increases, so does $y$.
# We can quantify this relationship by fitting a linear model:
#
# $$
# y = \theta_1 x + \theta_0,
# $$
#
# where $\theta_0$ is the intercept (bias) and $\theta_1$ is the slope.
#
# To find a good fit for our data, we need a way to measure how well the model fits.
# The most common metric is the **Root Mean Squared Error** (MSE):
#
# $$
# \mathrm{MSE} = \sqrt{ \frac{1}{m}\sum_{i=1}^m\left(y_i - (\theta_1 x_i + \theta_0) \right)^2}
# $$

# %%
# Import the Linear Regression model from scikit-learn
from sklearn.linear_model import LinearRegression

# Create an instance of the model
linreg = LinearRegression()

# Fit the model to the data
linreg.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# Since this is a 2D dataset, we can plot the fitted model.

# %%
# Generate 100 evenly spaced points for plotting
m = 100
x_plot = np.linspace(-1, 1, m).reshape(100, 1)  # 100 points in the interval [-1, 1]
y_plot = linreg.predict(x_plot)  # Use the linear model to predict y values

# Create the plot
fig, ax = plt.subplots(figsize=(12, 5))  # Set the figure size
plt.plot(x_plot, y_plot, c='red', label='Linear model')  # Plot the linear model in red

# Plot the original dataset
plt.scatter(x, y, label='Data points')  # Scatter plot of the actual data points
plt.legend(fontsize=15)  # Display the legend

# %% [markdown]
# In this code, we first generate 100 evenly spaced `x` values between -1 and 1 using `np.linspace()`. Then, we use the linear regression model (`linreg`) to predict the corresponding `y` values (`y_plot`). After that, we plot the predicted linear model as a red line and the original dataset as scatter points.

# %% [markdown]
# ## 2. Multivariable Linear Regression

# %% [markdown]
# In multivariable linear regression, we extend the idea of simple linear regression to handle multiple input variables (features).
# Instead of modeling the relationship between just two variables, we now model the relationship between a dependent variable $y$ and several independent variables $x_1, x_2, \dots, x_n$.
# The goal is the same: to find a linear equation that best fits the data.
#
# The general form of the model is:
#
# $$
# y = \theta_0 + \theta_1 x_1 + \theta_2 x_2 + \dots + \theta_n x_n
# $$
#
# Here:
# - $y$ is the target variable (what we're trying to predict).
# - $x_1, x_2, \dots, x_n$ are the input features.
# - $\theta_0$ is the intercept (bias term).
# - $\theta_1, \theta_2, \dots, \theta_n$ are the coefficients (weights) that determine how much each feature contributes to the prediction.

# %% [markdown]
# To train a linear model, we need to find the coefficients $\theta_i$ that minimize the **Root Mean Squared Error (RMSE)**:
#
# $$
# \mathrm{RMSE} = \sqrt{\frac{1}{n} \sum_{i=1}^n \left( \widehat{y}_i - y_i \right)^2}
# $$
#
# Here, $y_i$ represents the actual values of the target variable, and $\widehat{y}_i$ represents the predicted values. Minimizing the RMSE ensures that the model's predictions are as close as possible to the actual values.

# %% [markdown]
# ### Example: Sales Prediction

# %%
# load the data
path = 'https://raw.githubusercontent.com/justmarkham/scikit-learn-videos/master/data/Advertising.csv'
df = pd.read_csv(path, index_col=0)
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# **What are the features?**
#
# - **TV**: Advertising dollars spent on TV for a single product in a given market (in thousands of dollars).
# - **Radio**: Advertising dollars spent on radio ads (in thousands of dollars).
# - **Newspaper**: Advertising dollars spent on newspaper ads (in thousands of dollars).
#
# **What is the response?**
#
# - **Sales**: The number of units sold for a single product in a given market (in thousands of items).

# %% [markdown]
# **Goal:** Train a linear model to predict sales based on the money spent on different advertising platforms.
#
# $$
# y = \theta_0 + \theta_1 \times \text{TV} + \theta_2 \times \text{Radio} + \theta_3 \times \text{Newspaper}
# $$

# %% [markdown]
# ### Linear Regression in scikit-learn

# %%
# feature matrix X / target vector y
X = df[['TV', 'Radio', 'Newspaper']]
y = df.Sales

# %%
# train / test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Interpreting linear regression coefficients

# %% [markdown]
# Each coefficient in a linear regression model represents the change in the target variable (sales) for a one-unit increase in the corresponding feature, assuming all other features are held constant.

# %%
# coefficients
linreg.coef_
# Out:
# array([ 0.04651199,  0.18472519, -0.00398179])

# %%
# bias term
linreg.intercept_
# Out:
# 2.9456214089989743

# %%
# Pair the feature names with their corresponding coefficients
coeffs = pd.DataFrame(linreg.coef_, ['TV', 'Radio', 'Newspaper'], columns=['coefficient'])
coeffs
# Out:
#            coefficient
# TV            0.046512
# Radio         0.184725
# Newspaper    -0.003982

# %%
coeffs.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# How do we interpret the TV coefficient (0.0461)?
# For every additional $1,000 spent on TV ads, with radio and newspaper spending held constant, sales are expected to increase by approximately 0.0461 units (or 46 items).

# %% [markdown]
# ### Making predictions

# %% [markdown]
# Once the model is trained, we can use it to make predictions. By inputting new values for TV, radio, and newspaper ad spending, the model will estimate the expected sales based on the learned coefficients.

# %% [markdown]
# We  have a test set, let's use the model to predict the sales values for that data.

# %%
y_test_pred = linreg.predict(X_test)
y_test_pred
# Out:
# array([20.35510353, 23.97976148, 14.26886402, 16.75431928, 10.21122562,
#        17.38840416,  9.7085926 , 19.02371169, 17.09446826, 10.56798581,
#        16.67783848, 15.14756308, 10.06030491,  7.6259692 , 12.42517993,
#        11.30358026, 20.77679922, 15.29318088, 19.17767277, 16.35784729,
#        19.43267505, 20.73364309, 18.33301575, 15.54044828, 15.33731863,
#        24.03015387, 13.75844315, 13.88591397, 17.75879608,  5.95739665,
#         5.2564366 ,  7.11334567, 14.79122422, 17.10687873, 11.58547526,
#         4.42155319, 10.6766362 , 16.1459895 ,  7.34076838, 11.95972732,
#        23.12703009,  9.89257695, 11.09078567, 15.74251773, 18.09660252,
#         4.43783851, 22.76916708, 21.11474995, 14.95446281, 20.33974878])

# %% [markdown]
# ### Model evaluation

# %% [markdown]
# After making predictions on the test set, we need to evaluate how well the model performs. Common evaluation metrics for regression models include:
#
# - **Mean Squared Error (MSE)**: Measures the average squared difference between the actual and predicted values.
# - **Root Mean Squared Error (RMSE)**: The square root of the MSE, providing a more interpretable metric in the same units as the target variable.

# %% [markdown]
# **Root Mean Squared Error (RMSE)** is the square root of the average of the squared errors:
#
# $$
# \mathrm{RMSE} = \sqrt{\frac{1}{n} \sum_{i=1}^n (y_i - \hat{y}_i)^2}
# $$
#
# Where:
# - $n$ is the number of data points in the dataset.
# - $\hat{y}_i$ is the predicted value for $y_i$.

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_test_pred)
# Out:
# 2.155520474630065

# %% [markdown]
# On average, the predictions are off by 2,000 dollars.

# %% [markdown]
# ### Visualizing the Predictions

# %% [markdown]
# One effective way to evaluate the model’s performance is to plot the actual values against the predicted values. If the model is accurate, the points should lie close to a 45-degree line, where the actual and predicted values are equal.

# %%
# Plot actual vs predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', lw=2, label='Perfect Prediction')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs Predicted Sales')
plt.legend()

# %% [markdown]
# Data points below the red line were predicted lower than their actual value, while data points above the red line were predicted higher than their actual value.

# %% [markdown]
# This plot is useful because it provides a clear, visual way to evaluate the model’s performance. By comparing actual vs. predicted values:
#
# - **Close alignment to the red line** means the model is performing well, with predictions close to the actual values.
# - **Deviations from the line** show where the model struggles, highlighting areas where it overestimates or underestimate
# - It helps spot patterns of errors, such as systematic bias (e.g., consistently over- or under-predicting in certain range.acy.

# %% [markdown]
# ### Adding polynomial features

# %% [markdown]
# Just like we did to improve the classification model, we can build more complex pipelines. For example, let's add polynomial features to our regression model.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('poly_features', PolynomialFeatures(degree=3,include_bias=False)),
    ('reg', linreg)
])
pipe
# Out:
# Pipeline(steps=[('poly_features',
#                  PolynomialFeatures(degree=3, include_bias=False)),
#                 ('reg', LinearRegression())])

# %% [markdown]
# We use `include_bias=False` because the linear regression model already adds the intercept (bias) on its own. If we included it, we’d end up with duplicate columns, which isn’t needed.

# %%
# Fit the pipeline to the training data
pipe.fit(X_train, y_train)

# Predict on the test set
y_test_pred = pipe.predict(X_test)

# Plot actual vs predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', lw=2, label='Perfect Prediction')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs Predicted Sales (with Polynomial Features)')
plt.legend()

# %% [markdown]
# Notice that with degree 3 polynomial features, the predictions are much more accurate

# %% [markdown]
# The RMSE is also lower, showing that the model's predictions have improved.

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_test_pred)
# Out:
# 0.28451067733847

# %% [markdown]
# One drawback of using polynomial features is that we lose some interpretability.
# The meaning of the coefficients becomes less clear.
#
# Let me show you how to get all the coefficients along with their feature names:

# %%
# Get feature names from polynomial features
poly_feature_names = pipe.named_steps['poly_features'].get_feature_names_out()

# Pair the feature names with the coefficients
coeffs = pd.DataFrame(pipe.named_steps['reg'].coef_, index=poly_feature_names, columns=['Coefficient'])
coeffs
# Out:
#                      Coefficient
# TV                  8.876647e-02
# Radio               4.662995e-02
# Newspaper          -3.356196e-03
# TV^2               -4.535102e-04
# TV Radio            1.439645e-03
# TV Newspaper       -1.194362e-04
# Radio^2            -1.264151e-03
# Radio Newspaper     3.824104e-05
# Newspaper^2         3.051716e-04
# TV^3                8.195456e-07
# TV^2 Radio         -1.682665e-06
# TV^2 Newspaper      6.812686e-07
# TV Radio^2          4.859207e-06
# TV Radio Newspaper -3.875890e-06
# TV Newspaper^2     -1.896241e-07
# Radio^3             5.258100e-06
# Radio^2 Newspaper   6.759573e-06
# Radio Newspaper^2   3.508193e-06
# Newspaper^3        -3.063655e-06

# %%
coeffs.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## Decision trees and K-nearest neighbors

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor(max_depth=3)
tree_reg.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %% [markdown]
# At each leaf, the tree predicts the mean value instead of the majority class as in classification.

# %%
plt.figure(figsize=(20,7))
from sklearn.tree import plot_tree
plot_tree(tree_reg,
          feature_names = X_train.columns,
          filled=True,
          fontsize=10
         )
plt.show()

# %%
y_test_pred = tree_reg.predict(X_test)
mean_squared_error(y_test,y_test_pred)
# Out:
# 5.051047073349875

# %%
# Plot actual vs predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', lw=2, label='Perfect Prediction')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs Predicted Sales (decision tree)')
plt.legend()

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_reg = KNeighborsRegressor(n_neighbors=5)

# %% [markdown]
# kNN predicts the mean value of the $k$ nearest neighbors.

# %%
knn_reg.fit(X_train,y_train)
y_test_pred = knn_reg.predict(X_test)
mean_squared_error(y_test,y_test_pred)
# Out:
# 2.0296720000000015

# %%
# Plot actual vs predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', lw=2, label='Perfect Prediction')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs Predicted Sales (kNN)')
plt.legend()

# %% [markdown]
# ## Grid search

# %% [markdown]
# We can also use grid search to tune the hyperparameters of a regressor.
# The only thing to keep in mind is that scikit-learn’s built-in functions always try to maximize the scoring metric.
# Since we want to minimize the mean squared error, we instead **maximize the negative mean squared error**.

# %%
from sklearn.model_selection import GridSearchCV

# %%
len(X)
# Out:
# 200

# %%
param_grid = {
    'max_depth': [2, 3, 5, 7, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4, 8]
}

# Create the grid search
grid_search = GridSearchCV(
    estimator=tree_reg,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=1,
    n_jobs=-1
)

# Fit to your training data
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(max_depth=3), n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5, 7, 10],
#                          'min_samples_leaf': [1, 2, 4, 8],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
# best hyperparameter values
grid_search.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
tree_reg = grid_search.best_estimator_

# %%
y_test_pred = tree_reg.predict(X_test)
mean_squared_error(y_test,y_test_pred)
# Out:
# 0.7159888888888891

# %%
# Plot actual vs predicted values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test_pred, alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', lw=2, label='Perfect Prediction')
plt.xlabel('Actual Sales')
plt.ylabel('Predicted Sales')
plt.title('Actual vs Predicted Sales (decision tree)')
plt.legend()
